# %%
# !pip install xlrd

# %%
import pandas as pd
# we are using the inline backend
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
#improt the necessary library necessary for the initial step
import pandas as pd
#using the path of the excel file, call the file
data = pd.read_excel (r'C:\Users\USER\Documents\IBM DataScience\world analysis\world population\work.xlsx', skiprows=range(2)) 
#the first of the data is called
data.head()
# Out:
#          Unnamed: 0    Unnamed: 1    Unnamed: 2    Unnamed: 3    Unnamed: 4  \
# 0              Year  2.020000e+03  2.019000e+03  2.018000e+03  2.017000e+03
# 1  World population  7.794799e+09  7.713468e+09  7.631091e+09  7.547859e+09
# 2       Year change  1.050000e-02  1.080000e-02  1.100000e-02  1.120000e-02
# 3        Net change  8.133064e+07  8.237706e+07  8.323212e+07  8.383688e+07
# 4           Dnesity  5.200000e+01  5.200000e+01  5.100000e+01  5.100000e+01
#
#      Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9  ...  \
# 0  2.016000e+03  2.015000e+03  2.014000e+03  2.013000e+03  2.012000e+03  ...
# 1  7.464022e+09  7.379797e+09  7.295291e+09  7.210582e+09  7.125828e+09  ...
# 2  1.140000e-02  1.160000e-02  1.170000e-02  1.190000e-02  1.200000e-02  ...
# 3  8.422491e+07  8.450637e+07  8.470879e+07  8.475392e+07  8.463376e+07  ...
# 4  5.000000e+01  5.000000e+01  4.900000e+01  4.800000e+01  4.800000e+01  ...
#
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
#what then is the population of the world in the last five years from 2020 descending
ans = data.iloc[1,1], data.iloc[1,2], data.iloc[1,3], data.iloc[1,4], data.iloc[1,5]
ans
# Out:
# (7794798739.0, 7713468100.0, 7631091040.0, 7547858925.0, 7464022049.0)

# %%
years = data.iloc[0,1], data.iloc[0,2], data.iloc[0,3], data.iloc[0,4], data.iloc[0,5]
years
# Out:
# (2020.0, 2019.0, 2018.0, 2017.0, 2016.0)

# %%
#lets creat a bar chart to visualise how the progress had been
plt.barh(years,ans)
plt.title('World population Graph')
plt.xlabel('Population')
plt.ylabel('Years')
plt.show()

# %% [markdown]
# *lets limit the calculation to ony Africa for now.*
# first lets look at the individual countries of the world and we look at Africa.

# %%
#using the path of the excel file, call the file
new_data = pd.read_excel (r'C:\Users\USER\Documents\IBM DataScience\world analysis\world population\workcountry.xlsx', skiprows=range(2)) 
#the first of the data is called
new_data.head(10)
# Out:
#     # Country (or dependency)  Population (2020)  Yearly Change  Net Change  \
# 0   1                   China         1439323776         0.0039     5540090
# 1   2                   India         1380004385         0.0099    13586631
# 2   3           United States          331002651         0.0059     1937734
# 3   4               Indonesia          273523615         0.0107     2898047
# 4   5                Pakistan          220892340         0.0200     4327022
# 5   6                  Brazil          212559417         0.0072     1509890
# 6   7                 Nigeria          206139589         0.0258     5175990
# 7   8              Bangladesh          164689383         0.0101     1643222
# 8   9                  Russia          145934462         0.0004       62206
# 9  10                  Mexico          128932753         0.0106     1357224
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# ...

# %% [markdown]
# The table above shows the first 10 populated countries in the world at 2020. But how can we know which countries in Africa are more populated than the others? let's take take a look at an approach to find such a suituation. There are 54 counries in Africa, among them Nigeria is the most populated and the least populated is Saint Helena.

# %%
new_data.tail(10)
# Out:
#        #  Country (or dependency)  Population (2020)  Yearly Change  \
# 225  226          Wallis & Futuna              11239        -0.0169
# 226  227                    Nauru              10824         0.0063
# 227  228         Saint Barthelemy               9877         0.0030
# 228  229             Saint Helena               6077         0.0030
# 229  230  Saint Pierre & Miquelon               5794        -0.0048
# 230  231               Montserrat               4992         0.0006
# 231  232         Falkland Islands               3480         0.0305
# 232  233                     Niue               1626         0.0068
# 233  234                  Tokelau               1357         0.0127
# 234  235                 Holy See                801         0.0025
#
#      Net Change  Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate  \
# 225        -193               80              140             NaN       N.A.
# ...

# %%
new_data.shape
# Out:
# (235, 12)

# %%
#what then the is the population of these two countries.
new_data.iloc[199,1]
new_data.iloc[6,1]
print('The population of Nigeria is',new_data.iloc[6,2],' as that of Saint Helena is',new_data.iloc[228,2])
# Out:
# The population of Nigeria is 206139589  as that of Saint Helena is 6077

# %% [markdown]
# From the data that will be extracted, Saint Helena is not found inside therefore Seyshelle shall be the least populated country in Africa. Let's call a new data out and then analyse it.

# %%
#using the path of the excel file, call the file
new1_data = pd.read_excel (r'C:\Users\USER\Documents\IBM DataScience\world analysis\world population\africa.xlsx', skiprows=range(2)) 
#the first of the data is called
new1_data.head(10)
# Out:
#     # Country (or dependency)  Population (2020)  Yearly Change  Net Change  \
# 0   1                 Nigeria          206139589         0.0258     5175990
# 1   2                Ethiopia          114963588         0.0257     2884858
# 2   3                   Egypt          102334404         0.0194     1946331
# 3   4                DR Congo           89561403         0.0319     2770836
# 4   5            South Africa           59308690         0.0128      750420
# 5   6                Tanzania           59734218         0.0298     1728755
# 6   7                   Kenya           53771296         0.0228     1197323
# 7   8                  Uganda           45741007         0.0332     1471413
# 8   9                 Algeria           43851044         0.0185      797990
# 9  10                   Sudan           43849260         0.0242     1036022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net)  Fert. Rate  Med. Age  \
# ...

# %%
new1_data.tail()
# Out:
#      # Country (or dependency)  Population (2020)  Yearly Change  Net Change  \
# 52  53          Western Sahara             597339         0.0255       14876
# 53  54              Cabo Verde             555987         0.0110        6052
# 54  55                 Mayotte             272815         0.0250        6665
# 55  56     Sao Tome & Principe             219159         0.0191        4103
# 56  57              Seychelles              98347         0.0062         608
#
#     Density (P/Km²)  Land Area (Km²)  Migrants (net)  Fert. Rate  Med. Age  \
# 52                2           266000            5582         2.4        28
# 53              138             4030           -1342         2.3        28
# 54              728              375               0         3.7        20
# 55              228              960           -1680         4.4        19
# 56              214              460            -200         2.5        34
#
#     Urban Pop %  World Share
# ...

# %%
#What is the rank and population Ghana
new1_data[['Country (or dependency)']]
# Out:
#      Country (or dependency)
# 0                    Nigeria
# 1                   Ethiopia
# 2                      Egypt
# 3                   DR Congo
# 4               South Africa
# 5                   Tanzania
# 6                      Kenya
# 7                     Uganda
# 8                    Algeria
# 9                      Sudan
# 10                   Morocco
# 11                    Angola
# 12                     Ghana
# 13                Mozambique
# 14                Madagascar
# 15                  Cameroon
# 16             Côte d'Ivoire
# 17                     Niger
# 18              Burkina Faso
# 19                      Mali
# 20                    Malawi
# 21                    Zambia
# 22                   Senegal
# 23                      Chad
# 24                   Somalia
# 25                  Zimbabwe
# 26                    Guinea
# 27                    Rwanda
# 28                     Benin
# 29                   Tunisia
# 30                   Burundi
# ...

# %%
print(new1_data.iloc[12,1],'is ranked ',new1_data.iloc[12,0],' and has a population of ',new1_data.iloc[12,2])
# Out:
# Ghana is ranked  13  and has a population of  31072940

# %% [markdown]
# Let's create a visualisation graph for the data to better appreatiate it and also tell a story from it.

# %%
x = new1_data.iloc[0,1], new1_data.iloc[1,1], new1_data.iloc[2,1], new1_data.iloc[3,1], new1_data.iloc[4,1], new1_data.iloc[5,1], new1_data.iloc[6,1], new1_data.iloc[7,1], new1_data.iloc[8,1], new1_data.iloc[9,1] 
y = new1_data.iloc[0,2], new1_data.iloc[1,2], new1_data.iloc[2,2], new1_data.iloc[3,2], new1_data.iloc[4,2], new1_data.iloc[5,2], new1_data.iloc[6,2], new1_data.iloc[7,2], new1_data.iloc[8,2], new1_data.iloc[9,2]

#lets creat a bar chart to visualise how the progress had been
plt.barh(x,y)
plt.title('Africa population in 2020 Graph')
plt.xlabel('Countries')
plt.ylabel('Population')
plt.show()

# %%
# !pip3 install folium==0.5.0
import folium

print('Folium installed and imported!')
# Out:
# ...
# Folium installed and imported!

# %%
#7.9465° N, 1.0232° W
# Ghana latitude and longitude values
latitude = 7.9465
longitude = 1.0232

# create map and display it
gh_map = folium.Map(location=[latitude, longitude], zoom_start=12)

# display the map of San Francisco
gh_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS = false; L_NO_TOUCH = false; L_DISABLE_3D = false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
